# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import itertools

# %%
df = pd.read_csv("Project 1 Dataset.txt", delimiter='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806 entries, 0 to 805
# Data columns (total 10 columns):
# Notes             55 non-null object
# Year              751 non-null float64
# Year Code         751 non-null float64
# Age Group         751 non-null object
# Age Group Code    751 non-null object
# Sex               751 non-null object
# Sex Code          751 non-null object
# Race              751 non-null object
# Race Code         751 non-null object
# Deaths            751 non-null float64
# dtypes: float64(3), object(7)
# memory usage: 63.0+ KB

# %%
df.head()
# Out:
#   Notes    Year  Year Code    Age Group Age Group Code     Sex Sex Code  \
# 0   NaN  1999.0     1999.0  25-29 years          25-29  Female        F
# 1   NaN  1999.0     1999.0  25-29 years          25-29  Female        F
# 2   NaN  1999.0     1999.0  30-34 years          30-34  Female        F
# 3   NaN  1999.0     1999.0  30-34 years          30-34  Female        F
# 4   NaN  1999.0     1999.0  35-39 years          35-39  Female        F
#
#                         Race Race Code  Deaths
# 0  Black or African American    2054-5    25.0
# 1                      White    2106-3    59.0
# 2  Black or African American    2054-5   100.0
# 3                      White    2106-3   243.0
# 4  Asian or Pacific Islander      A-PI    22.0

# %%
del df['Notes']

# %%
df.tail(55)
# Out:
#      Year  Year Code Age Group Age Group Code  Sex Sex Code Race Race Code  \
# 751   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 752   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 753   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 754   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 755   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 756   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 757   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 758   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 759   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 760   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# 761   NaN        NaN       NaN            NaN  NaN      NaN  NaN       NaN
# ...

# %%
df.dropna()
# Out:
#        Year  Year Code     Age Group Age Group Code     Sex Sex Code  \
# 0    1999.0     1999.0   25-29 years          25-29  Female        F
# 1    1999.0     1999.0   25-29 years          25-29  Female        F
# 2    1999.0     1999.0   30-34 years          30-34  Female        F
# 3    1999.0     1999.0   30-34 years          30-34  Female        F
# 4    1999.0     1999.0   35-39 years          35-39  Female        F
# 5    1999.0     1999.0   35-39 years          35-39  Female        F
# 6    1999.0     1999.0   35-39 years          35-39  Female        F
# 7    1999.0     1999.0   40-44 years          40-44  Female        F
# 8    1999.0     1999.0   40-44 years          40-44  Female        F
# 9    1999.0     1999.0   40-44 years          40-44  Female        F
# 10   1999.0     1999.0   45-49 years          45-49  Female        F
# 11   1999.0     1999.0   45-49 years          45-49  Female        F
# 12   1999.0     1999.0   45-49 years          45-49  Female        F
# ...

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-482195c7ff1f> in <module>
# ----> 1 df.dropna()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
#               Year    Year Code       Deaths
# count   751.000000   751.000000   751.000000
# mean   2007.677763  2007.677763   983.818908
# std       5.206665     5.206665  1478.141080
# min    1999.000000  1999.000000    16.000000
# 25%    2003.000000  2003.000000    60.000000
# 50%    2008.000000  2008.000000   305.000000
# 75%    2012.000000  2012.000000   792.000000
# max    2016.000000  2016.000000  6322.000000

# %%
df.describe(include= 'object')
# Out:
#           Age Group Age Group Code     Sex Sex Code   Race Race Code
# count           751            751     751      751    751       751
# unique           13             13       1        1      4         4
# top     55-59 years          55-59  Female        F  White    2106-3
# freq             70             70     751      751    234       234

# %%
df2 = pd.df(group.describe().rename(columns={'analysis':name}).squeeze()
                for Race, group in df.groupby('Race'))

print(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-02e81bfabac3> in <module>
# ----> 1 df2 = pd.df(group.describe().rename(columns={'analysis':name}).squeeze()
#       2                 for Race, group in df.groupby('Race'))
#       3
#       4 print(df2)
#
# AttributeError: module 'pandas' has no attribute 'df'

# %%
df.shape
# Out:
# (806, 9)

# %%
Sources:
https://stackoverflow.com/questions/13411544/delete-column-from-pandas-dataframe
https://www.geeksforgeeks.org/python-delete-rows-columns-from-dataframe-using-pandas-drop/

# %%
df[df['Race']=="White"].describe()
# Out:
#               Year    Year Code       Deaths
# count   234.000000   234.000000   234.000000
# mean   2007.500000  2007.500000  2632.871795
# std       5.199249     5.199249  1711.615571
# min    1999.000000  1999.000000    27.000000
# 25%    2003.000000  2003.000000   934.000000
# 50%    2007.500000  2007.500000  3197.000000
# 75%    2012.000000  2012.000000  3805.750000
# max    2016.000000  2016.000000  6322.000000
